# %%
#import libraries

import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Downloads\Task_data_analytics\Exploratory_Project' # setting path variable as root

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'American_Housing_Data.csv')) # defining dataframe of orders.csv

# %%
df.head()
# Out:
#    Zip Code      Price  Beds  Baths  Living Space                Address  \
# 0     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 1     10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 2     10014  1650000.0     1      1           718  140 CHARLES ST APT 4D
# 3     10014   760000.0     3      2          1538            38 JONES ST
# 4     10014  1100000.0     1      1           600   81 BEDFORD ST APT 3F
#
#        City     State  Zip Code Population  Zip Code Density    County  \
# 0  New York  New York                29563           20967.9  New York
# 1  New York  New York                29563           20967.9  New York
# 2  New York  New York                29815           23740.9  New York
# 3  New York  New York                29815           23740.9  New York
# 4  New York  New York                29815           23740.9  New York
#
#    Median Household Income  Latitude  Longitude
# 0                 370046.0  40.72001  -74.00472
# ...

# %%
df.shape
# Out:
# (39981, 14)

# %%
df.describe()
# Out:
#               Price          Beds         Baths  Living Space  \
# count  3.998100e+04  39981.000000  39981.000000  39981.000000
# mean   6.227771e+05      3.171682      2.466572   1901.522723
# std    9.469793e+05      1.308796      1.323042   1211.307257
# min    1.800000e+03      1.000000      1.000000      2.000000
# 25%    2.650000e+05      3.000000      2.000000   1200.000000
# 50%    3.999000e+05      3.000000      2.000000   1639.000000
# 75%    6.749900e+05      4.000000      3.000000   2265.000000
# max    3.800000e+07     54.000000     66.000000  74340.000000
#
#        Zip Code Population  Zip Code Density  Median Household Income  \
# count         39981.000000      39981.000000             39979.000000
# mean          37726.201996       2379.412483            110837.259861
# std           18672.647445       2946.574792             47309.055715
# min               0.000000          0.000000             27475.000000
# ...

# %%
df['Zip Code'] = df['Zip Code'].astype('str')

# %%
# finding columns with missing values 
df.isnull().sum()
# Out:
# Zip Code                   0
# Price                      0
# Beds                       0
# Baths                      0
# Living Space               0
# Address                    0
# City                       0
# State                      0
# Zip Code Population        0
# Zip Code Density           0
# County                     0
# Median Household Income    2
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
# find duplicates
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
#       Zip Code      Price  Beds  Baths  Living Space                Address  \
# 1        10013  3999000.0     2      3          1967      74 GRAND ST APT 3
# 25       10301   575000.0     2      1          1200         15 PORTLAND PL
# 35       10301   950000.0     6      2          1920        76 HIGHLAND AVE
# 42       10302  1199999.0     3      4          3033       58 COLLFIELD AVE
# 56       10304   375000.0     3      2          1102          145 FULTON ST
# ...        ...        ...   ...    ...           ...                    ...
# 39902    98146   690000.0     3      3          1588      10434 11TH AVE SW
# 39904    98146   750000.0     2      1           730       3735 SW 100TH ST
# 39908    98164   599000.0     1      1           808  909 5TH AVE UNIT 2205
# 39924    98177   759950.0     2      2           890   11040 1ST AVE NW # B
# 39969    98199  1725000.0     4      4          2429        2619 34TH AVE W
#
# ...

# %%
# Remove duplicates
df = df.drop_duplicates()

# %%
df_dups = df[df.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Zip Code, Price, Beds, Baths, Living Space, Address, City, State, Zip Code Population, Zip Code Density, County, Median Household Income, Latitude, Longitude]
# Index: []

# %%
df.shape
# Out:
# (39019, 14)

# %%
# Check for mixed datatype in df
for col in df.columns.tolist():
  weird = (df[[col]].map(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df[weird]) > 0:
    print (col)

# %%
df.to_csv(os.path.join(path, '02 Data','Prepared Data', 'US_Housing_Data_Cleaned.csv'))
